# %%
from import_data import importData
import seaborn as sns
import matplotlib.pyplot as plt

# %%
gal = importData()
gal.head()
# Out:
#                  Object Name       RA       DEC  Velocity  Redshift  \
# 0  WISEA J000000.41+003333.0  0.00173   0.55922    183248  0.611248
# 1  WISEA J000001.17+004231.7  0.00476   0.70896    195489  0.652081
# 2  WISEA J000001.84+004425.7  0.00760   0.74049    166406  0.555072
# 3  WISEA J000002.96+151338.3  0.01224  15.22738    189644  0.632583
# 4  WISEA J000003.04+155633.9  0.01239  15.94275    178311  0.594782
#
#   Magnitude and Filter
# 0                23.2g
# 1                22.5g
# 2                22.0g
# 3                21.6g
# 4                22.3g

# %%
sns.jointplot(gal.RA, gal.DEC)

# %%
plt.figure(figsize=(8,4.2))
plt.subplot(111, projection="aitoff")
plt.scatter(gal.RA,gal.DEC, c=gal.Velocity, alpha=0.25)
plt.grid(True)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
c = ax.scatter(gal.RA, gal.Velocity, s=area, cmap='hsv', alpha=0.75)

# %%
X = gal.Velocity * np.sin(gal.RA) * np.cos(gal.DEC)
Y = gal.Velocity * np.sin(gal.RA) * np.sin(gal.DEC)
Z = gal.Velocity * np.cos(gal.DEC) 

from mpl_toolkits.mplot3d import Axes3D




fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X, Y, Z)

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
moment = fits.open('/home/kulik/Downloads/GalaxyZoo1_DR_table2.fits')
moment.info()
data = moment[1].data
print(data)
print(moment)
plt.imshow(data, origin='lower')
# plt.show()
# Out:
# Filename: /home/kulik/Downloads/GalaxyZoo1_DR_table2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      14   (1253,)   uint8
#   1                1 BinTableHDU     47   667944R x 16C   [K, 11A, 11A, I, E, E, E, E, E, E, E, E, E, I, I, I]
# [(587727178986356823, '00:00:00.41', '-10:22:25.7', 59, 0.61 , 0.034, 0.   , 0.153, 0.153, 0.051, 0.186, 0.61 , 0.186, 0, 0, 1)
#  (587727227300741210, '00:00:00.74', '-09:13:20.2', 18, 0.611, 0.   , 0.167, 0.222, 0.   , 0.   , 0.389, 0.203, 0.797, 1, 0, 0)
#  (587727225153257596, '00:00:01.03', '-10:56:48.0', 68, 0.735, 0.029, 0.   , 0.147, 0.074, 0.015, 0.176, 0.432, 0.428, 0, 0, 1)
#  ...
#  (587727223024124280, '23:59:58.81', '+15:39:49.4', 28, 0.286, 0.   , 0.071, 0.393, 0.179, 0.071, 0.464, 0.099, 0.603, 0, 0, 1)
#  (587730774425600239, '23:59:59.02', '+15:09:18.8', 23, 0.391, 0.   , 0.043, 0.   , 0.13 , 0.435, 0.043, 0.39 , 0.045, 0, 0, 1)
# ...
